# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import json

# %%
# Study data files
estimated_crimes_path = "estimated_crimes.csv"

# Read the  data and the study results
estimated_crimes = pd.read_csv(estimated_crimes_path)

estimated_crimes
# Out:
#       year state_abbr  population  violent_crime  homicide  rape_legacy  \
# 0     1995        NaN   262803276        1798792     21606        97470
# 1     1996        NaN   265228572        1688540     19645        96252
# 2     1997        NaN   267783607        1636099     18211        96153
# 3     1998        NaN   270248003        1533887     16974        93144
# 4     1999        NaN   272690813        1426044     15522        89411
# ...    ...        ...         ...            ...       ...          ...
# 1139  2012         WY      576626           1161        14          154
# 1140  2013         WY      583223           1212        17          144
# 1141  2014         WY      584304           1142        16          127
# 1142  2015         WY      586555           1300        16          171
# 1143  2016         WY      585501           1430        20          205
#
#       rape_revised  robbery  aggravated_assault  property_crime  burglary  \
# 0              NaN   580509             1099207        12063935   2593784
# 1              NaN   535594             1037049        11805323   2506400
# 2              NaN   498534             1023201        11558975   2461026
# 3              NaN   447186              976583        10951827   2332735
# 4              NaN   409371              911740        10208334   2100739
# ...            ...      ...                 ...             ...       ...
# 1139           NaN       61                 932           13222      2125
# 1140           NaN       74                 917           12809      1956
# 1141         204.0       53                 899           11477      1689
# 1142         124.0       59                1054           11151      1762
# 1143         150.0       59                1146           11460      1771
#
#       larceny  motor_vehicle_theft caveats
# 0     7997710              1472441     NaN
# 1     7904685              1394238     NaN
# 2     7743760              1354189     NaN
# 3     7376311              1242781     NaN
# 4     6955520              1152075     NaN
# ...       ...                  ...     ...
# 1139    10513                  584     NaN
# 1140    10275                  578     NaN
# 1141     9185                  603     NaN
# 1142     8797                  592     NaN
# 1143     8889                  800     NaN
#
# [1144 rows x 14 columns]

# %%
estimated_crimes_2006 = estimated_crimes[estimated_crimes['year'] >= int('2006')]
estimated_crimes_2006_09 = estimated_crimes_2006[estimated_crimes_2006['year'] <= int('2009')]
estimated_crimes_2006_09
# Out:
#       year state_abbr  population  violent_crime  homicide  rape_legacy  \
# 11    2006        NaN   299398484        1435123     17309        94472
# 12    2007        NaN   301621157        1422970     17128        92160
# 13    2008        NaN   304059724        1394461     16465        90750
# 14    2009        NaN   307006550        1325896     15399        89241
# 33    2006         AL     4599030          19553       382         1646
# ...    ...        ...         ...            ...       ...          ...
# 1114  2009         WI     5654774          14650       146         1118
# 1133  2006         WY      515004           1307        13          151
# 1134  2007         WY      522830           1344        21          172
# 1135  2008         WY      532668           1330        12          185
# 1136  2009         WY      544270           1196        11          172
#
#       rape_revised  robbery  aggravated_assault  property_crime  burglary  \
# 11             NaN   449246              874096        10019601   2194993
# 12             NaN   447324              866358         9882212   2190198
# 13             NaN   443563              843683         9774152   2228887
# 14             NaN   408742              812514         9337060   2203313
# 33             NaN     7062               10463          181249     44780
# ...            ...      ...                 ...             ...       ...
# 1114           NaN     4904                8482          147692     26813
# 1133           NaN       72                1071           15381      2322
# 1134           NaN       84                1067           15053      2365
# 1135           NaN       87                1046           14515      2198
# 1136           NaN       78                 935           14243      2176
#
#       larceny  motor_vehicle_theft caveats
# 11    6626363              1198245     NaN
# 12    6591542              1100472     NaN
# 13    6586206               959059     NaN
# 14    6338095               795652     NaN
# 33     121451                15018     NaN
# ...       ...                  ...     ...
# 1114   111947                 8932     NaN
# 1133    12255                  804     NaN
# 1134    11875                  813     NaN
# 1135    11584                  733     NaN
# 1136    11310                  757     NaN
#
# [208 rows x 14 columns]

# %%
crime_rates_06_09 = estimated_crimes_2006_09.drop(columns = ['rape_revised', 'caveats'], axis = 1)
crime_rates_06_09 = crime_rates_06_09.dropna()

crime_rates_06_09
# Out:
#       year state_abbr  population  violent_crime  homicide  rape_legacy  \
# 33    2006         AL     4599030          19553       382         1646
# 34    2007         AL     4627851          20775       412         1548
# 35    2008         AL     4661900          21110       351         1618
# 36    2009         AL     4708708          21194       322         1504
# 55    2006         AK      670053           4610        36          512
# ...    ...        ...         ...            ...       ...          ...
# 1114  2009         WI     5654774          14650       146         1118
# 1133  2006         WY      515004           1307        13          151
# 1134  2007         WY      522830           1344        21          172
# 1135  2008         WY      532668           1330        12          185
# 1136  2009         WY      544270           1196        11          172
#
#       robbery  aggravated_assault  property_crime  burglary  larceny  \
# 33       7062               10463          181249     44780   121451
# 34       7398               11417          184082     45379   124465
# 35       7346               11795          190416     50411   126539
# 36       6265               13103          178007     48844   118072
# 55        600                3462           23975      4155    17284
# ...       ...                 ...             ...       ...      ...
# 1114     4904                8482          147692     26813   111947
# 1133       72                1071           15381      2322    12255
# 1134       84                1067           15053      2365    11875
# 1135       87                1046           14515      2198    11584
# 1136       78                 935           14243      2176    11310
#
#       motor_vehicle_theft
# 33                  15018
# 34                  14238
# 35                  13466
# 36                  11091
# 55                   2536
# ...                   ...
# 1114                 8932
# 1133                  804
# 1134                  813
# 1135                  733
# 1136                  757
#
# [204 rows x 12 columns]

# %%
crime_rates_06_09["total_crime"]=crime_rates_06_09["violent_crime"]+ crime_rates_06_09["homicide"]+crime_rates_06_09["rape_legacy"]+crime_rates_06_09["robbery"]+ crime_rates_06_09["aggravated_assault"]+crime_rates_06_09["property_crime"]+crime_rates_06_09["burglary"]+crime_rates_06_09["larceny"]+crime_rates_06_09["motor_vehicle_theft"]
crime_rates_06_09
# Out:
#       year state_abbr  population  violent_crime  homicide  rape_legacy  \
# 33    2006         AL     4599030          19553       382         1646
# 34    2007         AL     4627851          20775       412         1548
# 35    2008         AL     4661900          21110       351         1618
# 36    2009         AL     4708708          21194       322         1504
# 55    2006         AK      670053           4610        36          512
# ...    ...        ...         ...            ...       ...          ...
# 1114  2009         WI     5654774          14650       146         1118
# 1133  2006         WY      515004           1307        13          151
# 1134  2007         WY      522830           1344        21          172
# 1135  2008         WY      532668           1330        12          185
# 1136  2009         WY      544270           1196        11          172
#
#       robbery  aggravated_assault  property_crime  burglary  larceny  \
# 33       7062               10463          181249     44780   121451
# 34       7398               11417          184082     45379   124465
# 35       7346               11795          190416     50411   126539
# 36       6265               13103          178007     48844   118072
# 55        600                3462           23975      4155    17284
# ...       ...                 ...             ...       ...      ...
# 1114     4904                8482          147692     26813   111947
# 1133       72                1071           15381      2322    12255
# 1134       84                1067           15053      2365    11875
# 1135       87                1046           14515      2198    11584
# 1136       78                 935           14243      2176    11310
#
#       motor_vehicle_theft  total_crime
# 33                  15018       401604
# 34                  14238       409714
# 35                  13466       423052
# 36                  11091       398402
# 55                   2536        57170
# ...                   ...          ...
# 1114                 8932       324684
# 1133                  804        33376
# 1134                  813        32794
# 1135                  733        31690
# 1136                  757        30878
#
# [204 rows x 13 columns]

# %%
crime_rates_06_09["crime_rate"]=crime_rates_06_09["total_crime"]/crime_rates_06_09["population"]*100
crime_rates_06_09
# Out:
#       year state_abbr  population  violent_crime  homicide  rape_legacy  \
# 33    2006         AL     4599030          19553       382         1646
# 34    2007         AL     4627851          20775       412         1548
# 35    2008         AL     4661900          21110       351         1618
# 36    2009         AL     4708708          21194       322         1504
# 55    2006         AK      670053           4610        36          512
# ...    ...        ...         ...            ...       ...          ...
# 1114  2009         WI     5654774          14650       146         1118
# 1133  2006         WY      515004           1307        13          151
# 1134  2007         WY      522830           1344        21          172
# 1135  2008         WY      532668           1330        12          185
# 1136  2009         WY      544270           1196        11          172
#
#       robbery  aggravated_assault  property_crime  burglary  larceny  \
# 33       7062               10463          181249     44780   121451
# 34       7398               11417          184082     45379   124465
# 35       7346               11795          190416     50411   126539
# 36       6265               13103          178007     48844   118072
# 55        600                3462           23975      4155    17284
# ...       ...                 ...             ...       ...      ...
# 1114     4904                8482          147692     26813   111947
# 1133       72                1071           15381      2322    12255
# 1134       84                1067           15053      2365    11875
# 1135       87                1046           14515      2198    11584
# 1136       78                 935           14243      2176    11310
#
#       motor_vehicle_theft  total_crime  crime_rate
# 33                  15018       401604    8.732363
# 34                  14238       409714    8.853224
# 35                  13466       423052    9.074669
# 36                  11091       398402    8.460962
# 55                   2536        57170    8.532161
# ...                   ...          ...         ...
# 1114                 8932       324684    5.741768
# 1133                  804        33376    6.480726
# 1134                  813        32794    6.272402
# 1135                  733        31690    5.949297
# 1136                  757        30878    5.673287
#
# [204 rows x 14 columns]

# %%
crime_rates_2006=crime_rates_06_09.loc[crime_rates_06_09["year"]==2006]
crime_rates_2006.reset_index(drop=True, inplace=True)
crime_rates_2006.head()
# Out:
#    year state_abbr  population  violent_crime  homicide  rape_legacy  robbery  \
# 0  2006         AL     4599030          19553       382         1646     7062
# 1  2006         AK      670053           4610        36          512      600
# 2  2006         AZ     6166318          33456       533         2449     9491
# 3  2006         AR     2810872          15538       205         1325     2749
# 4  2006         CA    36457549         194483      2486         9235    71142
#
#    aggravated_assault  property_crime  burglary  larceny  motor_vehicle_theft  \
# 0               10463          181249     44780   121451                15018
# 1                3462           23975      4155    17284                 2536
# 2               20983          294389     59418   178321                56650
# 3               11259          112025     31864    72646                 7515
# 4              111620         1159988    247230   669103               243655
#
#    total_crime  crime_rate
# 0       401604    8.732363
# 1        57170    8.532161
# 2       655690   10.633412
# 3       255126    9.076400
# 4      2708942    7.430401

# %%
crime_rates_2007=crime_rates_06_09.loc[crime_rates_06_09["year"]==2007]
crime_rates_2007.reset_index(drop=True, inplace=True)

crime_rates_2007.head()
# Out:
#    year state_abbr  population  violent_crime  homicide  rape_legacy  robbery  \
# 0  2007         AL     4627851          20775       412         1548     7398
# 1  2007         AK      683478           4520        43          545      581
# 2  2007         AZ     6338755          32835       548         2353     9764
# 3  2007         AR     2834797          15226       198         1294     3105
# 4  2007         CA    36553215         191561      2262         9046    70706
#
#    aggravated_assault  property_crime  burglary  larceny  motor_vehicle_theft  \
# 0               11417          184082     45379   124465                14238
# 1                3351           23096      3734    16929                 2433
# 2               20170          287308     59988   177076                50244
# 3               10629          112130     32035    73096                 6999
# 4              109547         1112510    237850   654526               220134
#
#    total_crime  crime_rate
# 0       409714    8.853224
# 1        55232    8.081021
# 2       640286   10.101132
# 3       254712    8.985194
# 4      2608142    7.135192

# %%
crime_rates_2008=crime_rates_06_09.loc[crime_rates_06_09["year"]==2008]
crime_rates_2008.reset_index(drop=True, inplace=True)

crime_rates_2008.head()
# Out:
#    year state_abbr  population  violent_crime  homicide  rape_legacy  robbery  \
# 0  2008         AL     4661900          21110       351         1618     7346
# 1  2008         AK      686293           4475        27          447      645
# 2  2008         AZ     6500180          31567       462         2200     9809
# 3  2008         AR     2855390          14649       165         1463     2777
# 4  2008         CA    36756666         185329      2142         8903    69388
#
#    aggravated_assault  property_crime  burglary  larceny  motor_vehicle_theft  \
# 0               11795          190416     50411   126539                13466
# 1                3356           20090      3237    15225                 1628
# 2               19096          266653     58606   169460                38587
# 3               10244          110360     33912    69905                 6543
# 4              104896         1080996    237811   650656               192529
#
#    total_crime  crime_rate
# 0       423052    9.074669
# 1        49130    7.158750
# 2       596440    9.175746
# 3       250018    8.756002
# 4      2532650    6.890315

# %%
crime_rates_2009=crime_rates_06_09.loc[crime_rates_06_09["year"]==2009]
crime_rates_2009.reset_index(drop=True, inplace=True)

crime_rates_2009.head()
# Out:
#    year state_abbr  population  violent_crime  homicide  rape_legacy  robbery  \
# 0  2009         AL     4708708          21194       322         1504     6265
# 1  2009         AK      698473           4424        22          513      654
# 2  2009         AZ     6595778          28128       380         2279     8199
# 3  2009         AR     2889450          14905       179         1378     2576
# 4  2009         CA    36961664         174934      1972         8713    64093
#
#    aggravated_assault  property_crime  burglary  larceny  motor_vehicle_theft  \
# 0               13103          178007     48844   118072                11091
# 1                3235           20538      3600    15251                 1687
# 2               17270          236721     54308   155976                26437
# 3               10772          109078     34753    68228                 6097
# 4              100156         1009433    230198   615402               163833
#
#    total_crime  crime_rate
# 0       398402    8.460962
# 1        49924    7.147592
# 2       529698    8.030865
# 3       247966    8.581772
# 4      2368734    6.408624

# %%
crimerates_allyears=pd.DataFrame({"state": crime_rates_2006["state_abbr"], 
                                 "crimerate_2006": crime_rates_2006["crime_rate"],
                                 "crimerate_2007": crime_rates_2007["crime_rate"],
                                 "crimerate_2008": crime_rates_2008["crime_rate"],
                                 "crimerate_2009": crime_rates_2009["crime_rate"]})
crimerates_allyears
# Out:
#    state  crimerate_2006  crimerate_2007  crimerate_2008  crimerate_2009
# 0     AL        8.732363        8.853224        9.074669        8.460962
# 1     AK        8.532161        8.081021        7.158750        7.147592
# 2     AZ       10.633412       10.101132        9.175746        8.030865
# 3     AR        9.076400        8.985194        8.756002        8.581772
# 4     CA        7.430401        7.135192        6.890315        6.408624
# 5     CO        7.667517        6.701985        6.349687        6.018929
# 6     CT        5.771670        5.543486        5.594970        5.298770
# 7     DE        8.354775        8.167778        8.606653        7.998445
# 8     DC       12.324730       12.662759       13.084772       12.201642
# 9     FL        9.405288        9.622654        9.658758        8.906596
# 10    GA        8.702874        8.762199        8.987849        8.201228
# 11    HI        9.001181        8.790794        7.678012        7.885557
# 12    ID        5.291773        5.064019        4.675105        4.531631
# 13    IL        7.122461        6.937924        6.915984        6.468145
# 14    IN        7.542100        7.413279        7.375621        6.892670
# 15    IA        6.218669        5.897031        5.456952        5.223987
# 16    KS        8.409323        8.335095        7.596782        7.264930
# 17    KY        5.743551        5.673311        5.958056        5.559150
# 18    LA        9.603971        9.890282        9.104570        8.971220
# 19    ME        5.325619        5.134197        5.166143        5.049833
# 20    MD        8.319315        8.146849        8.291612        7.576834
# 21    MA        5.783887        5.681766        5.726591        5.571505
# 22    MI        7.579012        7.194627        6.929869        6.697154
# 23    MN        6.785933        6.668859        6.258916        5.778725
# 24    MS        7.004130        6.810299        6.426831        6.489033
# 25    MO        8.759766        8.780428        8.330157        7.725859
# 26    MT        6.468127        6.571935        6.059911        5.666525
# 27    NE        7.307229        6.907472        6.383198        6.114819
# 28    NV        9.699346        9.081143        8.382462        7.537783
# 29    NH        4.235319        4.299954        4.626963        4.667912
# 30    NJ        5.258030        5.085978        5.239822        4.774259
# 31    NM        9.085956        8.983027        8.938416        8.692766
# 32    NY        4.999362        4.804565        4.783355        4.632685
# 33    NC        9.182787        9.096624        9.019070        8.136824
# 34    ND        4.596559        4.420406        4.511435        4.494438
# 35    OH        8.099403        7.647042        7.524053        7.186412
# 36    OK        8.249469        8.124698        8.010958        8.185948
# 37    OR        8.019546        7.673901        7.128014        6.521651
# 38    PA        5.781335        5.560392        5.644764        5.162650
# 39    RI        5.690093        5.671978        6.195541        5.741690
# 40    SC       10.091249       10.161016        9.942230        9.168950
# 41    SD        4.062569        3.957479        4.002517        3.977188
# 42    TN        9.800055        9.707248        9.525578        8.865271
# 43    TX        9.200766        9.265540        8.989610        9.012609
# 44    UT        7.477698        7.517323        7.201954        7.020756
# 45    VT        5.072863        4.991195        5.394434        5.097465
# 46    VA        5.546074        5.518555        5.579985        5.384398
# 47    WA        9.717599        8.767020        8.281012        8.031788
# 48    WV        5.835015        5.588855        5.618947        5.689598
# 49    WI        6.214229        6.270842        6.075480        5.741768
# 50    WY        6.480726        6.272402        5.949297        5.673287

# %%
multi_plot = crimerates_allyears.plot(kind="bar", figsize = (50, 25))
multi_plot.set_xticklabels(crimerates_allyears['state'], rotation = 90)

multi_plot.legend(fancybox=True, frameon=True, prop={'size':40})
plt.title('Crime Rates by State 2006-2009', fontsize=30)
#plt.legend("crimerate_2006")
plt.xlabel('State', fontsize=30)
plt.ylabel('Crime Rate', fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(labelsize=25)
plt.savefig('CrimeRatebyState2006-2009')
plt.show()

# %%
plt.figure(figsize=(30,15))
plt.bar(crimerates_allyears["state"], crimerates_allyears["crimerate_2006"], color="red")
plt.title('Crime Rates by State 2006', fontsize=30)
#plt.legend()
plt.xlabel('State', fontsize=30)
plt.ylabel('Crime Rate', fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(labelsize=25)

#plt.tick_params(axis='x', which='major',labelsize=2)
plt.savefig('CrimeRatebyState2006')
plt.show()

# %%
# Study data files
grad_rates_path = "GradRates.csv"

# Read the  data and the study results
grad_rates = pd.read_csv(grad_rates_path)

grad_rates
# Out:
#        Unnamed: 0     Year  State    LEAID  Total Dropouts  \
# 0               0  2006-07      1   100002               0
# 1               1  2006-07      1   100005              30
# 2               2  2006-07      1   100006              46
# 3               3  2006-07      1   100007              45
# 4               4  2006-07      1   100008               8
# ...           ...      ...    ...      ...             ...
# 73124       73124  2009-10     66  6600040              -1
# 73125       73125  2009-10     69  6900030              -1
# 73126       73126  2009-10     72  7200030              -9
# 73127       73127  2009-10     78  7800002             144
# 73128       73128  2009-10     78  7800030             136
#
#        Dropout Enroll base  Droupout Rate  Diploma Count  AFGEB  AFGR  TOTOHC
# 0                        0           -2.0             -1     -1  -1.0      -1
# 1                      749            4.0            192    263  73.0      14
# 2                     1209            3.8            216    456  47.4      28
# 3                     2726            1.7            779    878  88.7      10
# 4                     1968            0.4            562    576  97.6      10
# ...                    ...            ...            ...    ...   ...     ...
# 73124                   -1           -1.0             -1     -1  -1.0      -1
# 73125                   -1           -1.0             -1     -1  -1.0      -1
# 73126               145172           -9.0          25514  41984  60.8      -2
# 73127                 2591            5.6            463     -2  -2.0       0
# 73128                 2474            5.5            495   1269  39.0      21
#
# [73129 rows x 11 columns]

# %%
grad_rates = grad_rates.drop(columns = ['LEAID', 'AFGEB','TOTOHC'], axis = 1)
grad_rates = grad_rates.drop(columns = ['Unnamed: 0'], axis = 1)
grad_rates
# Out:
#           Year  State  Total Dropouts  Dropout Enroll base  Droupout Rate  \
# 0      2006-07      1               0                    0           -2.0
# 1      2006-07      1              30                  749            4.0
# 2      2006-07      1              46                 1209            3.8
# 3      2006-07      1              45                 2726            1.7
# 4      2006-07      1               8                 1968            0.4
# ...        ...    ...             ...                  ...            ...
# 73124  2009-10     66              -1                   -1           -1.0
# 73125  2009-10     69              -1                   -1           -1.0
# 73126  2009-10     72              -9               145172           -9.0
# 73127  2009-10     78             144                 2591            5.6
# 73128  2009-10     78             136                 2474            5.5
#
#        Diploma Count  AFGR
# 0                 -1  -1.0
# 1                192  73.0
# 2                216  47.4
# 3                779  88.7
# 4                562  97.6
# ...              ...   ...
# 73124             -1  -1.0
# 73125             -1  -1.0
# 73126          25514  60.8
# 73127            463  -2.0
# 73128            495  39.0
#
# [73129 rows x 7 columns]

# %%
state_abbr = {
    1: 'AL',
    2: 'AK',
    60: 'AS',
    4: 'AZ',
    5: 'AR',
    6: 'CA',
    8: 'CO',
    9: 'CT',
    10: 'DE',
    11: 'DC',
    12: 'FL',
    13: 'GA',
    66: 'GU',
    15: 'HI',
    16: 'ID',
    17: 'IL',
    18: 'IN',
    19: 'IA',
    20: 'KS',
    21: 'KY',
    22: 'LA',
    23: 'ME',
    24: 'MD',
    25: 'MA',
    26: 'MI',
    27: 'MN',
    28: 'MS',
    29: 'MO',
    30: 'MT',
    31: 'NE',
    32: 'NV',
    33: 'NH',
    34: 'NJ',
    35: 'NM',
    36: 'NY',
    37: 'NC',
    38: 'ND',
    69:'MP',
    39: 'OH',
    40: 'OK',
    41: 'OR',
    42: 'PA',
    72: 'PR',
    44: 'RI',
    45: 'SC',
    46: 'SD',
    47: 'TN',
    48: 'TX',
    49: 'UT',
    50: 'VT',
    78: 'VI',
    51: 'VA',
    53: 'WA',
    54: 'WV',
    55: 'WI',
    56: 'WY'
}
pprint(state_abbr)
# Out:
# {1: 'AL',
#  2: 'AK',
#  4: 'AZ',
#  5: 'AR',
#  6: 'CA',
#  8: 'CO',
#  9: 'CT',
#  10: 'DE',
#  11: 'DC',
#  12: 'FL',
#  13: 'GA',
#  15: 'HI',
#  16: 'ID',
#  17: 'IL',
#  18: 'IN',
#  19: 'IA',
#  20: 'KS',
#  21: 'KY',
#  22: 'LA',
#  23: 'ME',
#  24: 'MD',
#  25: 'MA',
#  26: 'MI',
#  27: 'MN',
#  28: 'MS',
#  29: 'MO',
#  30: 'MT',
#  31: 'NE',
#  32: 'NV',
#  33: 'NH',
#  34: 'NJ',
#  35: 'NM',
#  36: 'NY',
#  37: 'NC',
#  38: 'ND',
#  39: 'OH',
#  40: 'OK',
#  41: 'OR',
#  42: 'PA',
#  44: 'RI',
#  45: 'SC',
#  46: 'SD',
#  47: 'TN',
#  48: 'TX',
#  49: 'UT',
#  50: 'VT',
#  51: 'VA',
#  53: 'WA',
#  54: 'WV',
#  55: 'WI',
#  56: 'WY',
#  60: 'AS',
#  66: 'GU',
#  69: 'MP',
#  72: 'PR',
#  78: 'VI'}

# %%
grad_rates['state_abbr'] = grad_rates['State'].map(state_abbr)
grad_rates
# Out:
#           Year  State  Total Dropouts  Dropout Enroll base  Droupout Rate  \
# 0      2006-07      1               0                    0           -2.0
# 1      2006-07      1              30                  749            4.0
# 2      2006-07      1              46                 1209            3.8
# 3      2006-07      1              45                 2726            1.7
# 4      2006-07      1               8                 1968            0.4
# ...        ...    ...             ...                  ...            ...
# 73124  2009-10     66              -1                   -1           -1.0
# 73125  2009-10     69              -1                   -1           -1.0
# 73126  2009-10     72              -9               145172           -9.0
# 73127  2009-10     78             144                 2591            5.6
# 73128  2009-10     78             136                 2474            5.5
#
#        Diploma Count  AFGR state_abbr
# 0                 -1  -1.0         AL
# 1                192  73.0         AL
# 2                216  47.4         AL
# 3                779  88.7         AL
# 4                562  97.6         AL
# ...              ...   ...        ...
# 73124             -1  -1.0         GU
# 73125             -1  -1.0         MP
# 73126          25514  60.8         PR
# 73127            463  -2.0         VI
# 73128            495  39.0         VI
#
# [73129 rows x 8 columns]

# %%
grad_rates = grad_rates[grad_rates['Total Dropouts'] >= 0]
grad_rates = grad_rates[grad_rates['Dropout Enroll base'] >= 0]
grad_rates = grad_rates[grad_rates['Droupout Rate'] >= 0]
grad_rates = grad_rates[grad_rates['Diploma Count'] >= 0]
grad_rates = grad_rates[grad_rates['AFGR'] >= 0]

grad_rates
# Out:
#           Year  State  Total Dropouts  Dropout Enroll base  Droupout Rate  \
# 1      2006-07      1              30                  749            4.0
# 2      2006-07      1              46                 1209            3.8
# 3      2006-07      1              45                 2726            1.7
# 4      2006-07      1               8                 1968            0.4
# 7      2006-07      1              19                  317            6.0
# ...        ...    ...             ...                  ...            ...
# 72899  2009-10     56              13                  284            4.6
# 72900  2009-10     56              57                  969            5.9
# 72901  2009-10     56               5                  100            5.0
# 72906  2009-10     56              19                  399            4.8
# 73128  2009-10     78             136                 2474            5.5
#
#        Diploma Count  AFGR state_abbr
# 1                192  73.0         AL
# 2                216  47.4         AL
# 3                779  88.7         AL
# 4                562  97.6         AL
# 7                 70  61.9         AL
# ...              ...   ...        ...
# 72899             71  88.8         WY
# 72900            217  81.9         WY
# 72901             19  82.6         WY
# 72906             93  84.5         WY
# 73128            495  39.0         VI
#
# [26386 rows x 8 columns]

# %%
grad_rates_2006=grad_rates.loc[grad_rates["Year"]=="2006-07"]
grad_rates_2006.reset_index(drop=True, inplace=True)
grad_rates_2006
# Out:
#          Year  State  Total Dropouts  Dropout Enroll base  Droupout Rate  \
# 0     2006-07      1              30                  749            4.0
# 1     2006-07      1              46                 1209            3.8
# 2     2006-07      1              45                 2726            1.7
# 3     2006-07      1               8                 1968            0.4
# 4     2006-07      1              19                  317            6.0
# ...       ...    ...             ...                  ...            ...
# 8197  2006-07     56               0                   66            0.0
# 8198  2006-07     56              23                  359            6.4
# 8199  2006-07     56               0                   23            0.0
# 8200  2006-07     69              99                 2574            3.8
# 8201  2006-07     78             271                 4078            6.6
#
#       Diploma Count  AFGR state_abbr
# 0               192  73.0         AL
# 1               216  47.4         AL
# 2               779  88.7         AL
# 3               562  97.6         AL
# 4                70  61.9         AL
# ...             ...   ...        ...
# 8197             18  78.3         WY
# 8198            100  84.0         WY
# 8199              3  50.0         WY
# 8200            643  73.6         MP
# 8201            820  57.7         VI
#
# [8202 rows x 8 columns]

# %%
grad_rates_2006_bystate = grad_rates_2006.groupby(['state_abbr']).mean()
grad_rates_2006_bystate.reset_index(inplace=True)
grad_rates_2006_bystate
# Out:
#    state_abbr  State  Total Dropouts  Dropout Enroll base  Droupout Rate  \
# 0          AK    2.0       87.314286           902.142857      11.277143
# 1          AL    1.0       41.720339          1343.262712       3.564407
# 2          AR    5.0       29.909091           482.478469       5.689474
# 3          AZ    4.0       81.805755          1012.410072      17.746043
# 4          CA    6.0      250.907162          3302.689655      10.130769
# 5          CO    8.0      126.559055          1400.496063       7.071654
# 6          CT    9.0       33.431579          1080.778947       2.934737
# 7          DC   11.0     1256.000000         12145.000000      10.300000
# 8          DE   10.0       95.142857          1305.571429       7.438095
# 9          FL   12.0      461.272727          9314.060606       5.019697
# 10         GA   13.0      120.988506          2079.316092       6.580460
# 11         HI   15.0     2938.000000         42124.000000       7.000000
# 12         IA   19.0       15.738318           458.901869       2.022897
# 13         ID   16.0       23.779070           662.732558       2.420930
# 14         IL   17.0       64.102649           963.119205       6.336093
# 15         IN   18.0       34.576763           918.941909       3.273444
# 16         KS   20.0       19.000000           521.527473       3.043407
# 17         KY   21.0       39.744966           982.543624       3.346309
# 18         LA   22.0      187.898551          2042.565217       8.728986
# 19         MA   25.0       50.523810           903.704762       4.443810
# 20         MD   24.0      429.083333          8776.500000       4.745833
# 21         ME   23.0       29.524272           431.912621       6.594175
# 22         MI   26.0       72.508475           783.824859       8.164783
# 23         MN   27.0       32.705128           773.153846       5.660684
# 24         MO   29.0       29.270950           584.008380       3.836034
# 25         MP   69.0       99.000000          2574.000000       3.800000
# 26         MS   28.0       41.063830           743.049645       5.774468
# 27         MT   30.0        3.147059            98.117647       2.652941
# 28         NC   37.0      203.095652          2809.617391       7.612174
# 29         ND   38.0        7.642857           223.738095       1.601190
# 30         NE   31.0       15.806667           370.006667       1.222667
# 31         NH   33.0       32.084746           712.881356       4.477966
# 32         NJ   34.0       41.325153          1246.153374       2.985890
# 33         NM   35.0       84.867647          1072.323529       4.655882
# 34         NY   36.0       46.990706           974.460967       3.843680
# 35         OH   39.0       36.136564           821.971366       3.060132
# 36         OK   40.0       20.159468           416.581395       3.529900
# 37         OR   41.0       92.426667          1502.880000       5.982667
# 38         PA   42.0       52.053922          1199.872549       3.736275
# 39         RI   44.0       85.212121          1084.151515       5.896970
# 40         SC   45.0       99.185185          1989.567901       4.960494
# 41         SD   46.0       15.284091           257.204545       3.890909
# 42         TN   47.0       81.990991          1990.063063       2.627928
# 43         TX   48.0       63.404082          1269.402721       4.141088
# 44         UT   49.0      128.916667          3090.055556       3.952778
# 45         VA   51.0       83.000000          2406.166667       3.576667
# 46         VI   78.0      271.000000          4078.000000       6.600000
# 47         WA   53.0       78.247664          1179.518692       6.226636
# 48         WI   55.0       25.302521           749.533613       1.778992
# 49         WV   54.0       60.018519          1175.370370       4.687037
# 50         WY   56.0       34.342105           518.210526       4.481579
#
#     Diploma Count       AFGR
# 0      208.714286  67.094286
# 1      311.864407  67.037288
# 2      122.047847  81.101914
# 3      243.820144  71.335252
# 4      734.944297  70.654377
# 5      348.637795  78.949606
# 6      299.031579  81.471579
# 7     2489.000000  57.300000
# 8      319.761905  67.271429
# 9     2142.863636  64.822727
# 10     446.787356  62.479310
# 11   11063.000000  75.400000
# 12     129.705607  89.219626
# 13     175.197674  81.251163
# 14     243.539735  84.328477
# 15     227.410788  77.437759
# 16     142.351648  81.682418
# 17     252.630872  78.080537
# 18     484.057971  64.511594
# 19     252.004762  81.837619
# 20    2398.500000  81.904167
# 21     119.262136  82.673786
# 22     205.602637  80.315443
# 23     213.217949  87.221795
# 24     158.634078  83.787989
# 25     643.000000  73.600000
# 26     166.028369  63.106383
# 27      27.352941  83.188235
# 28     655.695652  68.895652
# 29      64.666667  85.932143
# 30     102.026667  91.077333
# 31     198.338983  82.581356
# 32     352.717791  85.234969
# 33     220.000000  66.808824
# 34     248.394052  81.160595
# 35     216.455947  83.093172
# 36     110.950166  81.819269
# 37     370.080000  74.080000
# 38     319.348039  83.046569
# 39     297.090909  81.609091
# 40     426.148148  59.416049
# 41      71.170455  83.948864
# 42     483.261261  75.826126
# 43     304.914286  76.773333
# 44     766.000000  77.655556
# 45     608.691667  73.036667
# 46     820.000000  57.700000
# 47     288.537383  77.371028
# 48     216.558824  91.648739
# 49     314.333333  80.527778
# 50     131.631579  75.963158

# %%
grad_rates_2007=grad_rates.loc[grad_rates["Year"]=="2007-08"]
grad_rates_2007.reset_index(drop=True, inplace=True)
grad_rates_2007.head()
# Out:
#       Year  State  Total Dropouts  Dropout Enroll base  Droupout Rate  \
# 0  2007-08      1              29                  939            3.1
# 1  2007-08      1              41                 1612            2.5
# 2  2007-08      1              38                 3817            1.0
# 3  2007-08      1              27                 2715            1.0
# 4  2007-08      1              15                  401            3.7
#
#    Diploma Count   AFGR state_abbr
# 0            172   69.6         AL
# 1            276   61.3         AL
# 2            899   91.9         AL
# 3            624  100.0         AL
# 4             72   67.3         AL

# %%
grad_rates_2007_bystate = grad_rates_2007.groupby(['state_abbr']).mean()
grad_rates_2007_bystate.reset_index(inplace=True)

grad_rates_2007_bystate.head()
# Out:
#   state_abbr  State  Total Dropouts  Dropout Enroll base  Droupout Rate  \
# 0         AK    2.0       85.942857          1149.542857      10.197143
# 1         AL    1.0       40.803571          1810.312500       2.580357
# 2         AR    5.0       30.136792           624.320755       4.485377
# 3         AZ    4.0       75.454545          1370.335664      11.965035
# 4         CA    6.0      219.329923          4137.488491       7.846036
#
#    Diploma Count       AFGR
# 0     212.942857  64.702857
# 1     343.446429  69.401786
# 2     128.641509  79.701887
# 3     263.650350  70.092308
# 4     780.309463  74.368031

# %%
grad_rates_2008=grad_rates.loc[grad_rates["Year"]=="2008-09"]
grad_rates_2008.reset_index(drop=True, inplace=True)
grad_rates_2008.head()
# Out:
#       Year  State  Total Dropouts  Dropout Enroll base  Droupout Rate  \
# 0  2008-09      1              21                  976            2.1
# 1  2008-09      1              21                 1671            1.3
# 2  2008-09      1              30                 3823            0.8
# 3  2008-09      1              19                 2820            0.7
# 4  2008-09      1              12                  397            3.0
#
#    Diploma Count   AFGR state_abbr
# 0            171   64.0         AL
# 1            325   67.0         AL
# 2            775   89.6         AL
# 3            663  100.0         AL
# 4             87   77.7         AL

# %%
grad_rates_2008_bystate = grad_rates_2008.groupby(['state_abbr']).mean()
grad_rates_2008_bystate.reset_index(inplace=True)

grad_rates_2008_bystate.head()
# Out:
#   state_abbr  State  Total Dropouts  Dropout Enroll base  Droupout Rate  \
# 0         AK    2.0       72.050000          1006.875000       8.642500
# 1         AL    1.0       30.277778          1859.611111       1.751852
# 2         AR    5.0       25.465438           599.258065       4.000461
# 3         AZ    4.0       74.391892          1323.094595      10.991216
# 4         CO    8.0      103.736842          1735.684211       4.132331
#
#    Diploma Count       AFGR
# 0     194.525000  65.995000
# 1     357.703704  70.660185
# 2     122.239631  76.007373
# 3     264.844595  74.558784
# 4     346.639098  78.447368

# %%
grad_rates_2009=grad_rates.loc[grad_rates["Year"]=="2009-10"]
grad_rates_2009.reset_index(drop=True, inplace=True)
grad_rates_2009.head()
# Out:
#       Year  State  Total Dropouts  Dropout Enroll base  Droupout Rate  \
# 0  2009-10      1              18                  327            5.5
# 1  2009-10      1              54                 1184            4.6
# 2  2009-10      1              39                  855            4.6
# 3  2009-10      1              58                  909            6.4
# 4  2009-10      1              43                  568            7.6
#
#    Diploma Count  AFGR state_abbr
# 0             49  48.5         AL
# 1            164  51.4         AL
# 2            162  66.1         AL
# 3            177  70.8         AL
# 4            117  65.0         AL

# %%
grad_rates_2009_bystate = grad_rates_2009.groupby(['state_abbr']).mean()
grad_rates_2009_bystate.reset_index(inplace=True)

grad_rates_2009_bystate.head()
# Out:
#   state_abbr  State  Total Dropouts  Dropout Enroll base  Droupout Rate  \
# 0         AK    2.0       86.312500          1191.031250      10.306250
# 1         AL    1.0       39.000000           699.166667       5.833333
# 2         AR    5.0       34.472222           578.902778       5.859722
# 3         AZ    4.0      105.392523           869.392523      17.188785
# 4         CA    6.0      374.586420          4444.617284      15.664198
#
#    Diploma Count       AFGR
# 0     237.968750  68.959375
# 1     122.666667  60.366667
# 2     117.111111  73.431944
# 3     135.084112  74.459813
# 4     827.802469  71.730247

# %%
gradrates_allyears=pd.DataFrame({"state": grad_rates_2006_bystate["state_abbr"], 
                                 "gradrate_2006": grad_rates_2006_bystate["AFGR"],
                                 "gradrate_2007": grad_rates_2007_bystate["AFGR"],
                                 "gradrate_2008": grad_rates_2008_bystate["AFGR"],
                                 "gradrate_2009": grad_rates_2009_bystate["AFGR"]})
gradrates_allyears
# Out:
#    state  gradrate_2006  gradrate_2007  gradrate_2008  gradrate_2009
# 0     AK      67.094286      64.702857      65.995000      68.959375
# 1     AL      67.037288      69.401786      70.660185      60.366667
# 2     AR      81.101914      79.701887      76.007373      73.431944
# 3     AZ      71.335252      70.092308      74.558784      74.459813
# 4     CA      70.654377      74.368031      78.447368      71.730247
# 5     CO      78.949606      78.541085      80.090526      70.718605
# 6     CT      81.471579      82.775248      62.050000      66.658333
# 7     DC      57.300000      59.175000      72.319048      60.481818
# 8     DE      67.271429      69.866667      68.650725      64.059322
# 9     FL      64.822727      66.247761      66.400000      75.400000
# 10    GA      62.479310      63.645614      75.300000      81.692105
# 11    HI      75.400000      76.000000      89.349524      95.000000
# 12    IA      89.219626      88.899459      80.915854      76.850000
# 13    ID      81.251163      79.827500      85.543052      66.307692
# 14    IL      84.328477      82.226144      78.081385      84.411111
# 15    IN      77.437759      76.906912      84.384884      63.028947
# 16    KS      81.682418      82.148000      78.645270      71.204878
# 17    KY      78.080537      76.850704      65.419718      71.866667
# 18    LA      64.511594      63.975362      82.827000      71.791026
# 19    MA      81.837619      81.136765      80.974000      81.632143
# 20    MD      81.904167      82.112500      79.464333      78.166000
# 21    ME      82.673786      80.577282      86.888235      73.315385
# 22    MI      80.315443      85.776389      84.350595      72.410256
# 23    MN      87.221795      84.279310      61.415862      75.350000
# 24    MO      83.787989      62.749306      84.210000      77.366667
# 25    MP      73.600000      85.134375      74.048387     100.000000
# 26    MS      63.106383      72.406349      86.762366      85.359524
# 27    MT      83.188235      86.574000      89.076552      66.886275
# 28    NC      68.895652      91.045513      83.787273      52.950000
# 29    ND      85.932143      83.582456      87.815625      71.616154
# 30    NE      91.077333      84.983432      68.515942      74.210526
# 31    NH      82.581356      71.197183      83.407034      77.828846
# 32    NJ      85.234969      81.856194      83.312076      77.672500
# 33    NM      66.808824      83.152110      82.010801      78.996875
# 34    NY      81.160595      81.578218      79.341259      72.725000
# 35    OH      83.093172      78.122759      85.365589      61.987500
# 36    OK      81.819269      85.297025      79.053125      77.675000
# 37    OR      74.080000      80.633333      65.136905      72.100000
# 38    PA      83.046569      85.715625      86.001020      76.619298
# 39    RI      81.609091      77.880734      79.858824      65.740000
# 40    SC      59.416049      76.757026      78.507692      69.950000
# 41    SD      83.948864      75.120513      79.960000      39.000000
# 42    TN      75.826126      74.817355      76.004132      90.000000
# 43    TX      76.773333      27.400000      30.800000      76.319231
# 44    UT      77.655556      75.181250      75.989952      85.671429
# 45    VA      73.036667      91.530380      92.274123      76.323810
# 46    VI      57.700000      79.266667      77.874074      77.043333
# 47    WA      77.371028      74.900000      81.326667            NaN
# 48    WI      91.648739            NaN            NaN            NaN
# 49    WV      80.527778            NaN            NaN            NaN
# 50    WY      75.963158            NaN            NaN            NaN

# %%
multi_plot_grad = gradrates_allyears.plot(kind="bar", figsize = (50, 25))
multi_plot_grad.set_xticklabels(gradrates_allyears['state'], rotation = 90)

multi_plot_grad.legend(fancybox=True, frameon=True, prop={'size':40})
plt.title('Graduation Rates by State 2006-2009', fontsize=30)
#plt.legend("crimerate_2006")
plt.xlabel('State', fontsize=30)
plt.ylabel('Graduation Rate', fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(labelsize=25)
plt.savefig('GradRates2006-2009')
plt.show()

# %%
#Selecting Crime rate Data for NY
crimerates_allyears.iloc[32]
# Out:
# state                  NY
# crimerate_2006    4.99936
# crimerate_2007    4.80457
# crimerate_2008    4.78335
# crimerate_2009    4.63269
# Name: 32, dtype: object

# %%
#Selecting Grad Rates for NY
gradrates_allyears.iloc[34]
# Out:
# state                 NY
# gradrate_2006    81.1606
# gradrate_2007    81.5782
# gradrate_2008    79.3413
# gradrate_2009     72.725
# Name: 34, dtype: object

# %%
#Create Data Frame for NY Grad Rates and Crime Rate
#Added (Shifted) 80 to Crime Rate data to compare slopes between Crime rates and Grad Rates. For better Visual Comparison
NY_grads_crime = {'Years': ['2006','2007', '2008', '2009'],
            'Grad Rate': [81.1606,81.5782,79.3413,72.725],
            'Crime Rate': [71.99936,71.80457,71.78335,71.63269]
        }

NY_grads_crime_df = pd.DataFrame(NY_grads_crime, columns = ['Years','Grad Rate','Crime Rate'])

NY_grads_crime_df
# Out:
#   Years  Grad Rate  Crime Rate
# 0  2006    81.1606    71.99936
# 1  2007    81.5782    71.80457
# 2  2008    79.3413    71.78335
# 3  2009    72.7250    71.63269

# %%
#Graphing NY Crime Rates and Grad Rates
NY_grads_crime_df.plot(x ='Years', y=['Grad Rate','Crime Rate'], kind = 'line', style = '.-')
plt.ylim(70,83)

#NY_grads_crime_df.plot(x ='Grad Rate', y='Crime Rate', kind = 'scatter')
plt.title('New York Crime and Graduation Rates 2006-09')
plt.savefig('NY-CrimeRates')
plt.show()

# %%
#Selecting Crime rate Data for NJ
crimerates_allyears.iloc[30]
# Out:
# state                  NJ
# crimerate_2006    5.25803
# crimerate_2007    5.08598
# crimerate_2008    5.23982
# crimerate_2009    4.77426
# Name: 30, dtype: object

# %%
#Selecting Grad Rates for NJ
gradrates_allyears.iloc[32]
# Out:
# state                 NJ
# gradrate_2006     85.235
# gradrate_2007    81.8562
# gradrate_2008    83.3121
# gradrate_2009    77.6725
# Name: 32, dtype: object

# %%
#Create Data Frame for NJ Grad Rates and Crime Rate
#Added (Shifted) 80 to Crime Rate data to compare slopes between Crime rates and Grad Rates. For better Visual Comparison
NJ_grads_crime = {'Years': ['2006','2007', '2008', '2009'],
            'Grad Rate': [85.235,81.8562,83.3121,77.6725],
            'Crime Rate': [75.25803,75.08598,75.23982,74.77426]
        }

NJ_grads_crime_df = pd.DataFrame(NJ_grads_crime, columns = ['Years','Grad Rate','Crime Rate'])

NJ_grads_crime_df
# Out:
#   Years  Grad Rate  Crime Rate
# 0  2006    85.2350    75.25803
# 1  2007    81.8562    75.08598
# 2  2008    83.3121    75.23982
# 3  2009    77.6725    74.77426

# %%
#Graphing NJ Crime Rates and Grad Rates
NJ_grads_crime_df.plot(x ='Years', y=['Grad Rate','Crime Rate'], kind = 'line', style = '.-')
plt.ylim()
#NJ_grads_crime_df.plot(x ='Grad Rate', y='Crime Rate', kind = 'bar')
plt.title('New Jersey Crime and Graduation Rates 2006-09')
plt.savefig('NJ-Crime Rates')
plt.show()

# %%
crimerates_allyears.iloc[8]
# Out:
# state                  DC
# crimerate_2006    12.3247
# crimerate_2007    12.6628
# crimerate_2008    13.0848
# crimerate_2009    12.2016
# Name: 8, dtype: object

# %%
gradrates_allyears.iloc[7]
# Out:
# state                 DC
# gradrate_2006       57.3
# gradrate_2007     59.175
# gradrate_2008     72.319
# gradrate_2009    60.4818
# Name: 7, dtype: object

# %%
DC_grads_crime = {'Years': ['2006','2007', '2008', '2009'],
            'Grad Rate': [57.3,59.175,72.319,60.4818],
            'Crime Rate': [52.3247,52.6628,53.0848,52.2016]
        }

DC_grads_crime_df = pd.DataFrame(DC_grads_crime, columns = ['Years','Grad Rate','Crime Rate'])

DC_grads_crime_df
# Out:
#   Years  Grad Rate  Crime Rate
# 0  2006    57.3000     52.3247
# 1  2007    59.1750     52.6628
# 2  2008    72.3190     53.0848
# 3  2009    60.4818     52.2016

# %%
#Graphing DC Crime Rates and Grad Rates
DC_grads_crime_df.plot(x ='Years', y=['Grad Rate','Crime Rate'], kind = 'line', style = '.-')

#DC_grads_crime_df.plot(x ='Grad Rate', y='Crime Rate', kind = 'bar')
plt.title('DC Crime and Graduation Rates 2006-09')
plt.savefig('DC-Crime Rates')
plt.show()

# %%
#Create a DF with average per state for GradRates
US_gradrate_avg =grad_rates.groupby(grad_rates["state_abbr"]).mean()
US_gradrate_avg.reset_index(inplace = True)
US_gradrate_avg
# Out:
#    state_abbr  State  Total Dropouts  Dropout Enroll base  Droupout Rate  \
# 0          AK    2.0       82.450704          1057.725352      10.050000
# 1          AL    1.0       37.781977          1646.200581       2.714535
# 2          AR    5.0       29.081690           570.301408       4.830986
# 3          AZ    4.0       82.770950          1164.852886      14.233892
# 4          CA    6.0      259.175269          3852.580645      10.134086
# 5          CO    8.0      125.020833          1703.643519       5.856713
# 6          CT    9.0       37.800687          1318.756014       2.532990
# 7          DC   11.0      309.090909          4158.727273       4.090909
# 8          DE   10.0       95.626667          1592.893333       6.084000
# 9          FL   12.0      397.896714         10986.000000       3.664789
# 10         GA   13.0      118.003472          2473.425347       5.135938
# 11         HI   15.0     2799.500000         50662.500000       5.625000
# 12         IA   19.0       23.279753           603.068006       2.325657
# 13         ID   16.0       19.108000           807.292000       1.765600
# 14         IL   17.0       96.830932          1173.002882       6.861768
# 15         IN   18.0       28.797721          1134.723647       2.492593
# 16         KS   20.0       18.321755           637.131627       2.414625
# 17         KY   21.0       37.621868          1185.498861       2.507517
# 18         LA   22.0      165.291498          2319.137652       6.974494
# 19         MA   25.0       49.622901          1122.299237       3.549924
# 20         MD   24.0      420.509804          9979.372549       4.207843
# 21         ME   23.0       24.561576           474.428571       5.340394
# 22         MI   26.0       62.494274           975.218204       6.205063
# 23         MN   27.0       28.350501           913.755365       4.433476
# 24         MO   29.0       36.029304           715.384615       3.637179
# 25         MP   69.0       99.000000          2574.000000       3.800000
# 26         MS   28.0       41.418605           875.151163       5.008837
# 27         MT   30.0        5.577982           118.596330       4.766972
# 28         NC   37.0      185.383747          3218.896163       6.186230
# 29         ND   38.0        7.662021           250.564460       1.461672
# 30         NE   31.0       14.115217           441.989130       1.121522
# 31         NH   33.0       26.401163           843.953488       3.366860
# 32         NJ   34.0       81.857639          1512.776042       4.320139
# 33         NM   35.0       84.610039          1347.606178       4.912355
# 34         NV   32.0     2213.500000         43406.000000       4.750000
# 35         NY   36.0      108.071959          1344.410051       4.016619
# 36         OH   39.0       39.984214           979.648593       3.476939
# 37         OK   40.0       18.418876           503.108165       3.035737
# 38         OR   41.0       55.282878          1226.962779       3.620596
# 39         PA   42.0       39.482821          1230.237794       2.521609
# 40         RI   44.0       80.084112          1364.607477       4.899065
# 41         SC   45.0       92.469613          2231.281768       4.299448
# 42         SD   46.0       10.414966           292.989796       2.290816
# 43         TN   47.0      100.831288          2547.855828       2.438957
# 44         TX   48.0       61.328455          1553.433922       3.569694
# 45         UT   49.0      150.183333          3798.308333       3.917500
# 46         VA   51.0       81.716931          2824.291005       3.158466
# 47         VI   78.0      223.500000          2944.000000       7.675000
# 48         VT   50.0       22.545455           434.090909       5.227273
# 49         WA   53.0       84.352609          1467.720733       5.547391
# 50         WI   55.0       29.853556           945.304045       1.635146
# 51         WV   54.0       66.868852          1450.551913       4.321311
# 52         WY   56.0       30.540146           630.153285       4.370803
#
#     Diploma Count       AFGR
# 0      212.352113  66.615493
# 1      333.238372  68.828198
# 2      123.574648  78.349014
# 3      233.229050  72.515270
# 4      770.192473  72.403118
# 5      354.381944  77.853704
# 6      308.597938  81.473196
# 7      770.636364  60.572727
# 8      338.826667  69.313333
# 9     2216.882629  66.286854
# 10     471.109375  64.158160
# 11   11295.500000  75.525000
# 12     141.782071  88.728130
# 13     179.920000  80.795600
# 14     250.225744  83.664553
# 15     238.545584  77.279345
# 16     146.749543  82.770932
# 17     261.810934  77.873121
# 18     477.246964  64.394737
# 19     261.676336  81.255878
# 20    2397.549020  81.411765
# 21     115.926108  81.836453
# 22     215.723930  79.360699
# 23     212.270386  86.445780
# 24     167.288462  83.860256
# 25     643.000000  73.600000
# 26     166.306977  62.416744
# 27      28.688073  82.863303
# 28     675.261851  71.955305
# 29      60.714286  86.056098
# 30     102.073913  90.167609
# 31     205.273256  83.400000
# 32     358.439236  85.896181
# 33     255.810811  68.481853
# 34    7285.000000  52.950000
# 35     287.123929  81.348087
# 36     217.309540  82.835758
# 37     112.695652  81.580064
# 38     256.823821  77.758065
# 39     281.861664  84.726492
# 40     312.261682  79.574766
# 41     442.801105  62.298343
# 42      67.707483  84.953741
# 43     548.763804  77.729141
# 44     324.316401  77.313861
# 45     754.083333  77.103333
# 46     617.730159  74.425926
# 47     540.000000  38.725000
# 48     105.272727  90.000000
# 49     294.928068  76.205783
# 50     227.721060  91.691771
# 51     326.622951  78.890164
# 52     138.051095  77.071533

# %%
#Merging to get rid of extra states that are not included in crime rate
CrimevsGrad = pd.merge(crime_rates_06_09, US_gradrate_avg, on= 'state_abbr', how = 'left')
CrimevsGrad
# Out:
#      year state_abbr  population  violent_crime  homicide  rape_legacy  \
# 0    2006         AL     4599030          19553       382         1646
# 1    2007         AL     4627851          20775       412         1548
# 2    2008         AL     4661900          21110       351         1618
# 3    2009         AL     4708708          21194       322         1504
# 4    2006         AK      670053           4610        36          512
# ..    ...        ...         ...            ...       ...          ...
# 199  2009         WI     5654774          14650       146         1118
# 200  2006         WY      515004           1307        13          151
# 201  2007         WY      522830           1344        21          172
# 202  2008         WY      532668           1330        12          185
# 203  2009         WY      544270           1196        11          172
#
#      robbery  aggravated_assault  property_crime  burglary  larceny  \
# 0       7062               10463          181249     44780   121451
# 1       7398               11417          184082     45379   124465
# 2       7346               11795          190416     50411   126539
# 3       6265               13103          178007     48844   118072
# 4        600                3462           23975      4155    17284
# ..       ...                 ...             ...       ...      ...
# 199     4904                8482          147692     26813   111947
# 200       72                1071           15381      2322    12255
# 201       84                1067           15053      2365    11875
# 202       87                1046           14515      2198    11584
# 203       78                 935           14243      2176    11310
#
#      motor_vehicle_theft  total_crime  crime_rate  State  Total Dropouts  \
# 0                  15018       401604    8.732363    1.0       37.781977
# 1                  14238       409714    8.853224    1.0       37.781977
# 2                  13466       423052    9.074669    1.0       37.781977
# 3                  11091       398402    8.460962    1.0       37.781977
# 4                   2536        57170    8.532161    2.0       82.450704
# ..                   ...          ...         ...    ...             ...
# 199                 8932       324684    5.741768   55.0       29.853556
# 200                  804        33376    6.480726   56.0       30.540146
# 201                  813        32794    6.272402   56.0       30.540146
# 202                  733        31690    5.949297   56.0       30.540146
# 203                  757        30878    5.673287   56.0       30.540146
#
#      Dropout Enroll base  Droupout Rate  Diploma Count       AFGR
# 0            1646.200581       2.714535     333.238372  68.828198
# 1            1646.200581       2.714535     333.238372  68.828198
# 2            1646.200581       2.714535     333.238372  68.828198
# 3            1646.200581       2.714535     333.238372  68.828198
# 4            1057.725352      10.050000     212.352113  66.615493
# ..                   ...            ...            ...        ...
# 199           945.304045       1.635146     227.721060  91.691771
# 200           630.153285       4.370803     138.051095  77.071533
# 201           630.153285       4.370803     138.051095  77.071533
# 202           630.153285       4.370803     138.051095  77.071533
# 203           630.153285       4.370803     138.051095  77.071533
#
# [204 rows x 20 columns]

# %%
CrimevsGrad["robbery rate"] = (CrimevsGrad["robbery"]/CrimevsGrad['population'])*10000
CrimevsGrad["homicide rate"] = (CrimevsGrad["homicide"]/CrimevsGrad['population'])*10000
CrimevsGrad["motor_vehicle_theft rate"] = (CrimevsGrad["motor_vehicle_theft"]/CrimevsGrad['population'])*10000
CrimevsGrad["rape_legacy rate"] = (CrimevsGrad["rape_legacy"]/CrimevsGrad['population'])*10000

# %%
#Mean and Median of Crime Rate
crime_mean = round(CrimevsGrad['crime_rate'].astype('float').mean(), 2)
crime_median = round(CrimevsGrad['crime_rate'].astype('float').median(), 2)
print("Crime Mean: "+str(crime_mean))
print("Crime Median: "+str(crime_median))
# Out:
# Crime Mean: 7.18
# Crime Median: 7.13

# %%
#Mean and Median of Graduation Rate
grad_mean = round(CrimevsGrad['AFGR'].astype('float').mean(), 2)
grad_median = round(CrimevsGrad['AFGR'].astype('float').median(), 2)
print("Graduation Mean: "+str(grad_mean))
print("Graduation Median: "+str(grad_median))
# Out:
# Graduation Mean: 77.32
# Graduation Median: 78.35

# %%
#Find the Correlation between Crime Rate and Graduation Rate
correlation = CrimevsGrad.corr()
print("Correlation: "+ str(round(correlation["crime_rate"][-1],2)))
# Out:
# Correlation: 0.21

# %%
# Creating a Linear Regression between Crime Rates and Grad Rates
x_values = CrimevsGrad['AFGR']
y_values = CrimevsGrad['crime_rate']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Graduation Rate')
plt.ylabel("Crime Rate")
plt.title(" Graduation Rate VS Crime Rate")
plt.show()

# %%
#Correlation
CrimevsGrad.corr()
# Out:
#                               year  population  violent_crime  homicide  \
# year                      1.000000    0.008342      -0.022270 -0.034922
# population                0.008342    1.000000       0.967869  0.961066
# violent_crime            -0.022270    0.967869       1.000000  0.977115
# homicide                 -0.034922    0.961066       0.977115  1.000000
# rape_legacy              -0.020091    0.934035       0.937688  0.922093
# robbery                  -0.022388    0.981837       0.981159  0.975799
# aggravated_assault       -0.021628    0.940054       0.993405  0.959313
# property_crime           -0.021588    0.960511       0.968576  0.957503
# burglary                  0.002734    0.924296       0.946040  0.934709
# larceny                  -0.013570    0.959190       0.960393  0.944680
# motor_vehicle_theft      -0.093712    0.895452       0.910877  0.922378
# total_crime              -0.021763    0.965143       0.976573  0.963821
# crime_rate               -0.139847    0.089056       0.219687  0.236978
# State                     0.000000   -0.083251      -0.140065 -0.157734
# Total Dropouts            0.000000   -0.050932      -0.004795 -0.024773
# Dropout Enroll base       0.000000   -0.046731       0.005865 -0.019674
# Droupout Rate             0.000000    0.235495       0.266717  0.309492
# Diploma Count             0.000000   -0.046909       0.001818 -0.022149
# AFGR                      0.000000   -0.050292      -0.155627 -0.185281
# robbery rate             -0.034183    0.209425       0.271715  0.301251
# homicide rate            -0.061529    0.046133       0.134759  0.209721
# motor_vehicle_theft rate -0.251982    0.126800       0.211199  0.240473
# rape_legacy rate         -0.050085   -0.280315      -0.200087 -0.225942
#
#                           rape_legacy   robbery  aggravated_assault  \
# year                        -0.020091 -0.022388           -0.021628
# population                   0.934035  0.981837            0.940054
# violent_crime                0.937688  0.981159            0.993405
# homicide                     0.922093  0.975799            0.959313
# rape_legacy                  1.000000  0.911072            0.925896
# robbery                      0.911072  1.000000            0.953379
# aggravated_assault           0.925896  0.953379            1.000000
# property_crime               0.965590  0.950514            0.956776
# burglary                     0.955055  0.916390            0.940471
# larceny                      0.962153  0.941007            0.949225
# motor_vehicle_theft          0.867748  0.919881            0.887776
# total_crime                  0.965354  0.958335            0.965450
# crime_rate                   0.219933  0.149434            0.255149
# State                       -0.085192 -0.140202           -0.141219
# Total Dropouts              -0.056271  0.006145           -0.006114
# Dropout Enroll base         -0.046970  0.011338            0.007710
# Droupout Rate                0.243003  0.271334            0.259029
# Diploma Count               -0.051600  0.007409            0.003712
# AFGR                        -0.092870 -0.121117           -0.177100
# robbery rate                 0.194703  0.293639            0.258795
# homicide rate                0.065802  0.127333            0.140607
# motor_vehicle_theft rate     0.182952  0.207062            0.210587
# rape_legacy rate            -0.064963 -0.261784           -0.170878
#
#                           property_crime  burglary   larceny  ...     State  \
# year                           -0.021588  0.002734 -0.013570  ...  0.000000
# population                      0.960511  0.924296  0.959190  ... -0.083251
# violent_crime                   0.968576  0.946040  0.960393  ... -0.140065
# homicide                        0.957503  0.934709  0.944680  ... -0.157734
# rape_legacy                     0.965590  0.955055  0.962153  ... -0.085192
# robbery                         0.950514  0.916390  0.941007  ... -0.140202
# aggravated_assault              0.956776  0.940471  0.949225  ... -0.141219
# property_crime                  1.000000  0.988519  0.995634  ... -0.089259
# burglary                        0.988519  1.000000  0.980854  ... -0.098678
# larceny                         0.995634  0.980854  1.000000  ... -0.063041
# motor_vehicle_theft             0.903187  0.870827  0.865858  ... -0.178769
# total_crime                     0.999406  0.986350  0.994495  ... -0.096636
# crime_rate                      0.254921  0.302418  0.239556  ... -0.267240
# State                          -0.089259 -0.098678 -0.063041  ...  1.000000
# Total Dropouts                 -0.032312 -0.028128 -0.046511  ... -0.125540
# Dropout Enroll base            -0.020895 -0.014507 -0.033402  ... -0.111907
# Droupout Rate                   0.249668  0.244025  0.212910  ... -0.383089
# Diploma Count                  -0.022024 -0.017762 -0.032664  ... -0.122862
# AFGR                           -0.137716 -0.185840 -0.110322  ...  0.299028
# robbery rate                    0.228960  0.227242  0.223330  ... -0.285795
# homicide rate                   0.092000  0.109950  0.079282  ... -0.261234
# motor_vehicle_theft rate        0.207525  0.201765  0.175050  ... -0.269401
# rape_legacy rate               -0.196214 -0.156614 -0.215077  ... -0.170202
#
#                           Total Dropouts  Dropout Enroll base  Droupout Rate  \
# year                            0.000000             0.000000       0.000000
# population                     -0.050932            -0.046731       0.235495
# violent_crime                  -0.004795             0.005865       0.266717
# homicide                       -0.024773            -0.019674       0.309492
# rape_legacy                    -0.056271            -0.046970       0.243003
# robbery                         0.006145             0.011338       0.271334
# aggravated_assault             -0.006114             0.007710       0.259029
# property_crime                 -0.032312            -0.020895       0.249668
# burglary                       -0.028128            -0.014507       0.244025
# larceny                        -0.046511            -0.033402       0.212910
# motor_vehicle_theft             0.028516             0.027297       0.388847
# total_crime                    -0.028620            -0.017265       0.252970
# crime_rate                      0.231209             0.227953       0.298077
# State                          -0.125540            -0.111907      -0.383089
# Total Dropouts                  1.000000             0.995803       0.118806
# Dropout Enroll base             0.995803             1.000000       0.083846
# Droupout Rate                   0.118806             0.083846       1.000000
# Diploma Count                   0.990043             0.989730       0.084092
# AFGR                           -0.354314            -0.359621      -0.384818
# robbery rate                    0.187853             0.177653       0.134738
# homicide rate                   0.043063             0.026401       0.155941
# motor_vehicle_theft rate        0.385375             0.371472       0.358581
# rape_legacy rate               -0.022269            -0.029460       0.172474
#
#                           Diploma Count      AFGR  robbery rate  \
# year                           0.000000  0.000000     -0.034183
# population                    -0.046909 -0.050292      0.209425
# violent_crime                  0.001818 -0.155627      0.271715
# homicide                      -0.022149 -0.185281      0.301251
# rape_legacy                   -0.051600 -0.092870      0.194703
# robbery                        0.007409 -0.121117      0.293639
# aggravated_assault             0.003712 -0.177100      0.258795
# property_crime                -0.022024 -0.137716      0.228960
# burglary                      -0.017762 -0.185840      0.227242
# larceny                       -0.032664 -0.110322      0.223330
# motor_vehicle_theft            0.021444 -0.163351      0.225944
# total_crime                   -0.018803 -0.140716      0.235746
# crime_rate                     0.217177 -0.640901      0.649443
# State                         -0.122862  0.299028     -0.285795
# Total Dropouts                 0.990043 -0.354314      0.187853
# Dropout Enroll base            0.989730 -0.359621      0.177653
# Droupout Rate                  0.084092 -0.384818      0.134738
# Diploma Count                  1.000000 -0.306697      0.151082
# AFGR                          -0.306697  1.000000     -0.501351
# robbery rate                   0.151082 -0.501351      1.000000
# homicide rate                  0.006303 -0.548340      0.880735
# motor_vehicle_theft rate       0.339712 -0.565889      0.768781
# rape_legacy rate              -0.054350 -0.228937     -0.123312
#
#                           homicide rate  motor_vehicle_theft rate  \
# year                          -0.061529                 -0.251982
# population                     0.046133                  0.126800
# violent_crime                  0.134759                  0.211199
# homicide                       0.209721                  0.240473
# rape_legacy                    0.065802                  0.182952
# robbery                        0.127333                  0.207062
# aggravated_assault             0.140607                  0.210587
# property_crime                 0.092000                  0.207525
# burglary                       0.109950                  0.201765
# larceny                        0.079282                  0.175050
# motor_vehicle_theft            0.107219                  0.333499
# total_crime                    0.098272                  0.208815
# crime_rate                     0.687605                  0.763092
# State                         -0.261234                 -0.269401
# Total Dropouts                 0.043063                  0.385375
# Dropout Enroll base            0.026401                  0.371472
# Droupout Rate                  0.155941                  0.358581
# Diploma Count                  0.006303                  0.339712
# AFGR                          -0.548340                 -0.565889
# robbery rate                   0.880735                  0.768781
# homicide rate                  1.000000                  0.716378
# motor_vehicle_theft rate       0.716378                  1.000000
# rape_legacy rate               0.035333                  0.089977
#
#                           rape_legacy rate
# year                             -0.050085
# population                       -0.280315
# violent_crime                    -0.200087
# homicide                         -0.225942
# rape_legacy                      -0.064963
# robbery                          -0.261784
# aggravated_assault               -0.170878
# property_crime                   -0.196214
# burglary                         -0.156614
# larceny                          -0.215077
# motor_vehicle_theft              -0.149770
# total_crime                      -0.197489
# crime_rate                        0.205990
# State                            -0.170202
# Total Dropouts                   -0.022269
# Dropout Enroll base              -0.029460
# Droupout Rate                     0.172474
# Diploma Count                    -0.054350
# AFGR                             -0.228937
# robbery rate                     -0.123312
# homicide rate                     0.035333
# motor_vehicle_theft rate          0.089977
# rape_legacy rate                  1.000000
#
# [23 rows x 23 columns]

# %%
#Grad Rates vs Robbery Rates
x_values = CrimevsGrad['AFGR']
y_values = CrimevsGrad['robbery rate']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Graduation Rate')
plt.ylabel("Robbery Rate")
plt.title(" Graduation Rate VS Robbery Rate")
plt.show()

#Correlation 
print("Correlation: "+ str(round(correlation["AFGR"][-4],2)))
# Out:
# Correlation: -0.5

# %%
x_values = CrimevsGrad['AFGR']
y_values = CrimevsGrad['homicide rate']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Graduation Rate')
plt.ylabel("Homicide Rate")
plt.title(" Graduation Rate VS Homicide Rate")
plt.show()

#Correlation 
print("Correlation: "+ str(round(correlation["AFGR"][-3],2)))
# Out:
# Correlation: -0.55

# %%
#Grad Rates vs Motor Vehicle Theft Rates
x_values = CrimevsGrad['AFGR']
y_values = CrimevsGrad['motor_vehicle_theft rate']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Graduation Rate')
plt.ylabel("Motor Vehicle Theft rate")
plt.title(" Graduation Rate VS Motor Vehicle Theft Rate")
plt.show()

#Correlation 
print("Correlation: "+ str(round(correlation["AFGR"][-2],2)))
# Out:
# Correlation: -0.57

# %%
#Grad Rates vs Rape Legacy Rates
x_values = CrimevsGrad['AFGR']
y_values = CrimevsGrad['rape_legacy rate']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Graduation Rate')
plt.ylabel("Rape Legacy rate")
plt.title(" Graduation Rate VS Rape Legacy Rate")
plt.show()

#Correlation 
print("Correlation: "+ str(round(correlation["AFGR"][-1],2)))
# Out:
# Correlation: -0.23

# %%
stat_summary_crimerate = crimerates_allyears.describe()
stat_summary_crimerate
# Out:
#        crimerate_2006  crimerate_2007  crimerate_2008  crimerate_2009
# count       51.000000       51.000000       51.000000       51.000000
# mean         7.476347        7.313372        7.141929        6.786688
# std          1.848196        1.868485        1.791580        1.644892
# min          4.062569        3.957479        4.002517        3.977188
# 25%          5.782611        5.672644        5.685678        5.565327
# 50%          7.542100        7.194627        6.929869        6.521651
# 75%          8.880474        8.785611        8.494557        8.031326
# max         12.324730       12.662759       13.084772       12.201642

# %%
outlier_crimerate_2006 = stat_summary_crimerate.loc["std","crimerate_2006"]*2
outlier_crimerate_2007 = stat_summary_crimerate.loc["std","crimerate_2007"]*2
outlier_crimerate_2008 = stat_summary_crimerate.loc["std","crimerate_2008"]*2
outlier_crimerate_2009 = stat_summary_crimerate.loc["std","crimerate_2009"]*2

# %%
mean_crimerate_2006 = stat_summary_crimerate.loc["mean","crimerate_2006"]
mean_crimerate_2007 = stat_summary_crimerate.loc["mean","crimerate_2007"]
mean_crimerate_2008 = stat_summary_crimerate.loc["mean","crimerate_2008"]
mean_crimerate_2009 = stat_summary_crimerate.loc["mean","crimerate_2009"]

# %%
print(f"2006 Crime rate Roughly 95% of the data is between {round(mean_crimerate_2006-outlier_crimerate_2006,3)} and {round(mean_crimerate_2006+outlier_crimerate_2006,3)}")
print(f"2007 Crime rate Roughly 95% of the data is between {round(mean_crimerate_2007-outlier_crimerate_2007,3)} and {round(mean_crimerate_2007+outlier_crimerate_2007,3)}")
print(f"2008 Crime rate Roughly 95% of the data is between {round(mean_crimerate_2008-outlier_crimerate_2008,3)} and {round(mean_crimerate_2008+outlier_crimerate_2008,3)}")
print(f"2009 Crime rate Roughly 95% of the data is between {round(mean_crimerate_2008-outlier_crimerate_2009,3)} and {round(mean_crimerate_2009+outlier_crimerate_2009,3)}")
# Out:
# 2006 Crime rate Roughly 95% of the data is between 3.78 and 11.173
# 2007 Crime rate Roughly 95% of the data is between 3.576 and 11.05
# 2008 Crime rate Roughly 95% of the data is between 3.559 and 10.725
# 2009 Crime rate Roughly 95% of the data is between 3.852 and 10.076

# %%
outlier_crime_states_2006 = crimerates_allyears.loc[(crimerates_allyears["crimerate_2006"]<= round(mean_crimerate_2006-outlier_crimerate_2006,3))
                                                   |(crimerates_allyears["crimerate_2007"]<= round(mean_crimerate_2007-outlier_crimerate_2007,3))
                                                   |(crimerates_allyears["crimerate_2008"]<= round(mean_crimerate_2008-outlier_crimerate_2008,3))
                                                   | (crimerates_allyears["crimerate_2009"]<= round(mean_crimerate_2009-outlier_crimerate_2009,3))
                                                   | (crimerates_allyears["crimerate_2006"]>= round(mean_crimerate_2006+outlier_crimerate_2006,3))
                                                   | (crimerates_allyears["crimerate_2007"]>= round(mean_crimerate_2007+outlier_crimerate_2007,3))
                                                   | (crimerates_allyears["crimerate_2008"]>= round(mean_crimerate_2008+outlier_crimerate_2008,3))
                                                   | (crimerates_allyears["crimerate_2009"]>= round(mean_crimerate_2009+outlier_crimerate_2009,3))]
outlier_crime_states_2006
# Out:
#   state  crimerate_2006  crimerate_2007  crimerate_2008  crimerate_2009
# 8    DC        12.32473       12.662759       13.084772       12.201642

# %%
grad_stat_summary = gradrates_allyears.describe()
grad_stat_summary
# Out:
#        gradrate_2006  gradrate_2007  gradrate_2008  gradrate_2009
# count      51.000000      48.000000      48.000000      47.000000
# mean       76.750412      76.794091      77.482878      73.475198
# std         8.604973      10.500512      10.143287      10.115428
# min        57.300000      27.400000      30.800000      39.000000
# 25%        70.994814      73.877610      74.431185      69.454687
# 50%        78.949606      78.903876      79.402796      73.431944
# 75%        82.627571      82.869463      83.892955      77.673750
# max        91.648739      91.530380      92.274123     100.000000

# %%
grad_2006_sd = grad_stat_summary.loc["std","gradrate_2006"]
grad_2006_sd
# Out:
# 8.604972803474595

# %%
outlr_grad_2006_sd = grad_2006_sd * 2
outlr_grad_2006_sd
# Out:
# 17.20994560694919

# %%
grad_2007_sd = grad_stat_summary.loc["std","gradrate_2007"]
grad_2007_sd
# Out:
# 10.500511601585437

# %%
outlr_grad_2007_sd = grad_2007_sd * 2
outlr_grad_2007_sd
# Out:
# 21.001023203170874

# %%
grad_2008_sd = grad_stat_summary.loc["std","gradrate_2008"]
grad_2008_sd
# Out:
# 10.1432873977949

# %%
outlr_grad_2008_sd = grad_2008_sd * 2
outlr_grad_2008_sd
# Out:
# 20.2865747955898

# %%
grad_2009_sd = grad_stat_summary.loc["std","gradrate_2009"]
grad_2009_sd
# Out:
# 10.115428334986616

# %%
outlr_grad_2009_sd = grad_2009_sd * 2
outlr_grad_2009_sd
# Out:
# 20.23085666997323

# %%
grad_2006_mean = grad_stat_summary.loc["mean","gradrate_2006"]
grad_2007_mean = grad_stat_summary.loc["mean","gradrate_2007"]
grad_2008_mean = grad_stat_summary.loc["mean","gradrate_2008"]
grad_2009_mean = grad_stat_summary.loc["mean","gradrate_2009"]

# %%
print(f"2006 graduation rate Roughly 95% of the data is between {round(grad_2006_mean-outlr_grad_2006_sd,3)} and {round(grad_2006_mean+outlr_grad_2006_sd,3)}")
print(f"2007 graduation rate Roughly 95% of the data is between {round(grad_2007_mean-outlr_grad_2006_sd,3)} and {round(grad_2007_mean+outlr_grad_2006_sd,3)}")
print(f"2008 graduation rate Roughly 95% of the data is between {round(grad_2008_mean-outlr_grad_2006_sd,3)} and {round(grad_2008_mean+outlr_grad_2006_sd,3)}")
print(f"2009 graduation rate Roughly 95% of the data is between {round(grad_2009_mean-outlr_grad_2006_sd,3)} and {round(grad_2009_mean+outlr_grad_2006_sd,3)}")
# Out:
# 2006 graduation rate Roughly 95% of the data is between 59.54 and 93.96
# 2007 graduation rate Roughly 95% of the data is between 59.584 and 94.004
# 2008 graduation rate Roughly 95% of the data is between 60.273 and 94.693
# 2009 graduation rate Roughly 95% of the data is between 56.265 and 90.685

# %%
outlier_grad_states = crimerates_allyears.loc[(crimerates_allyears["crimerate_2006"]<= round(mean_crimerate_2006-outlier_crimerate_2006,3))
                                                   |(crimerates_allyears["crimerate_2007"]<= round(mean_crimerate_2007-outlier_crimerate_2007,3))
                                                   |(crimerates_allyears["crimerate_2008"]<= round(mean_crimerate_2008-outlier_crimerate_2008,3))
                                                   | (crimerates_allyears["crimerate_2009"]<= round(mean_crimerate_2009-outlier_crimerate_2009,3))
                                                   | (crimerates_allyears["crimerate_2006"]>= round(mean_crimerate_2006+outlier_crimerate_2006,3))
                                                   | (crimerates_allyears["crimerate_2007"]>= round(mean_crimerate_2007+outlier_crimerate_2007,3))
                                                   | (crimerates_allyears["crimerate_2008"]>= round(mean_crimerate_2008+outlier_crimerate_2008,3))
                                                   | (crimerates_allyears["crimerate_2009"]>= round(mean_crimerate_2009+outlier_crimerate_2009,3))]
outlier_grad_states
# Out:
#   state  crimerate_2006  crimerate_2007  crimerate_2008  crimerate_2009
# 8    DC        12.32473       12.662759       13.084772       12.201642

# %%
multi_plot_grad = gradrates_allyears.plot(kind="bar", figsize = (50, 25))
multi_plot_grad.set_xticklabels(gradrates_allyears['state'], rotation = 90)

multi_plot_grad.legend(fancybox=True, frameon=True, prop={'size':40})
plt.title('Graduation Rates by State 2006-2009', fontsize=30)
#plt.legend("crimerate_2006")
plt.xlabel('State', fontsize=30)
plt.ylabel('Graduation Rate', fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(labelsize=25)

plt.show()

# %%
mean_gradrates_allyears = gradrates_allyears["gradrate_2006"] + gradrates_allyears["gradrate_2007"] + gradrates_allyears["gradrate_2008"] + gradrates_allyears["gradrate_2009"]
mean_gradrates_allyears = mean_gradrates_allyears/4
mean_gradrates_allyears
# Out:
# 0     66.687879
# 1     66.866481
# 2     77.560780
# 3     72.611539
# 4     73.800006
# 5     77.074956
# 6     73.238790
# 7     62.318966
# 8     67.462035
# 9     68.217622
# 10    70.779257
# 11    83.937381
# 12    83.971235
# 13    78.232352
# 14    82.261779
# 15    75.439626
# 16    78.420141
# 17    73.054407
# 18    70.776246
# 19    81.395132
# 20    80.411750
# 21    80.863672
# 22    80.713171
# 23    77.066742
# 24    77.028490
# 25    83.195691
# 26    76.908655
# 27    81.431265
# 28    74.169609
# 29    82.236594
# 30    79.696808
# 31    78.753605
# 32    82.018935
# 33    77.742152
# 34    78.701268
# 35    77.142255
# 36    80.961105
# 37    72.987560
# 38    82.845628
# 39    76.272162
# 40    71.157692
# 41    69.507344
# 42    79.161903
# 43    52.823141
# 44    78.624547
# 45    83.291245
# 46    72.971019
# 47          NaN
# 48          NaN
# 49          NaN
# 50          NaN
# dtype: float64

# %%
crimerates_allyears_mean = crimerates_allyears["crimerate_2006"] + crimerates_allyears["crimerate_2007"] + crimerates_allyears["crimerate_2008"] + crimerates_allyears["crimerate_2009"]
crimerates_allyears_mean
# Out:
# 0     35.121218
# 1     30.919524
# 2     37.941154
# 3     35.399368
# 4     27.864531
# 5     26.738118
# 6     22.208896
# 7     33.127651
# 8     50.273903
# 9     37.593296
# 10    34.654150
# 11    33.355545
# 12    19.562528
# 13    27.444513
# 14    29.223671
# 15    22.796639
# 16    31.606130
# 17    22.934067
# 18    37.570043
# 19    20.675792
# 20    32.334610
# 21    22.763749
# 22    28.400662
# 23    25.492432
# 24    26.730293
# 25    33.596211
# 26    24.766498
# 27    26.712719
# 28    34.700733
# 29    17.830149
# 30    20.358089
# 31    35.700165
# 32    19.219967
# 33    35.435305
# 34    18.022838
# 35    30.456911
# 36    32.571073
# 37    29.343112
# 38    22.149142
# 39    23.299302
# 40    39.363444
# 41    15.999753
# 42    37.898152
# 43    36.468525
# 44    29.217730
# 45    20.555958
# 46    22.029012
# 47    34.797418
# 48    22.732415
# 49    24.302319
# 50    24.375712
# dtype: float64

# %%
combined_mean_crime_with_state = pd.DataFrame({
    "state":crimerates_allyears["state"],
    "Mean_crime_Years": crimerates_allyears_mean
    
})

combined_mean_crime_with_state
# Out:
#    state  Mean_crime_Years
# 0     AL         35.121218
# 1     AK         30.919524
# 2     AZ         37.941154
# 3     AR         35.399368
# 4     CA         27.864531
# 5     CO         26.738118
# 6     CT         22.208896
# 7     DE         33.127651
# 8     DC         50.273903
# 9     FL         37.593296
# 10    GA         34.654150
# 11    HI         33.355545
# 12    ID         19.562528
# 13    IL         27.444513
# 14    IN         29.223671
# 15    IA         22.796639
# 16    KS         31.606130
# 17    KY         22.934067
# 18    LA         37.570043
# 19    ME         20.675792
# 20    MD         32.334610
# 21    MA         22.763749
# 22    MI         28.400662
# 23    MN         25.492432
# 24    MS         26.730293
# 25    MO         33.596211
# 26    MT         24.766498
# 27    NE         26.712719
# 28    NV         34.700733
# 29    NH         17.830149
# 30    NJ         20.358089
# 31    NM         35.700165
# 32    NY         19.219967
# 33    NC         35.435305
# 34    ND         18.022838
# 35    OH         30.456911
# 36    OK         32.571073
# 37    OR         29.343112
# 38    PA         22.149142
# 39    RI         23.299302
# 40    SC         39.363444
# 41    SD         15.999753
# 42    TN         37.898152
# 43    TX         36.468525
# 44    UT         29.217730
# 45    VT         20.555958
# 46    VA         22.029012
# 47    WA         34.797418
# 48    WV         22.732415
# 49    WI         24.302319
# 50    WY         24.375712

# %%
combined_mean_grad_with_state = pd.DataFrame({
    "state": gradrates_allyears["state"],
    "Mean_grad_rate" : mean_gradrates_allyears
})

combined_mean_grad_with_state
# Out:
#    state  Mean_grad_rate
# 0     AK       66.687879
# 1     AL       66.866481
# 2     AR       77.560780
# 3     AZ       72.611539
# 4     CA       73.800006
# 5     CO       77.074956
# 6     CT       73.238790
# 7     DC       62.318966
# 8     DE       67.462035
# 9     FL       68.217622
# 10    GA       70.779257
# 11    HI       83.937381
# 12    IA       83.971235
# 13    ID       78.232352
# 14    IL       82.261779
# 15    IN       75.439626
# 16    KS       78.420141
# 17    KY       73.054407
# 18    LA       70.776246
# 19    MA       81.395132
# 20    MD       80.411750
# 21    ME       80.863672
# 22    MI       80.713171
# 23    MN       77.066742
# 24    MO       77.028490
# 25    MP       83.195691
# 26    MS       76.908655
# 27    MT       81.431265
# 28    NC       74.169609
# 29    ND       82.236594
# 30    NE       79.696808
# 31    NH       78.753605
# 32    NJ       82.018935
# 33    NM       77.742152
# 34    NY       78.701268
# 35    OH       77.142255
# 36    OK       80.961105
# 37    OR       72.987560
# 38    PA       82.845628
# 39    RI       76.272162
# 40    SC       71.157692
# 41    SD       69.507344
# 42    TN       79.161903
# 43    TX       52.823141
# 44    UT       78.624547
# 45    VA       83.291245
# 46    VI       72.971019
# 47    WA             NaN
# 48    WI             NaN
# 49    WV             NaN
# 50    WY             NaN

# %%
merge_crime_Grad = pd.merge(combined_mean_crime_with_state, combined_mean_grad_with_state, how="outer", on="state")
merge_crime_Grad = merge_crime_Grad.dropna(how = "any")
merge_crime_Grad
# Out:
#    state  Mean_crime_Years  Mean_grad_rate
# 0     AL         35.121218       66.866481
# 1     AK         30.919524       66.687879
# 2     AZ         37.941154       72.611539
# 3     AR         35.399368       77.560780
# 4     CA         27.864531       73.800006
# 5     CO         26.738118       77.074956
# 6     CT         22.208896       73.238790
# 7     DE         33.127651       67.462035
# 8     DC         50.273903       62.318966
# 9     FL         37.593296       68.217622
# 10    GA         34.654150       70.779257
# 11    HI         33.355545       83.937381
# 12    ID         19.562528       78.232352
# 13    IL         27.444513       82.261779
# 14    IN         29.223671       75.439626
# 15    IA         22.796639       83.971235
# 16    KS         31.606130       78.420141
# 17    KY         22.934067       73.054407
# 18    LA         37.570043       70.776246
# 19    ME         20.675792       80.863672
# 20    MD         32.334610       80.411750
# 21    MA         22.763749       81.395132
# 22    MI         28.400662       80.713171
# 23    MN         25.492432       77.066742
# 24    MS         26.730293       76.908655
# 25    MO         33.596211       77.028490
# 26    MT         24.766498       81.431265
# 27    NE         26.712719       79.696808
# 29    NH         17.830149       78.753605
# 30    NJ         20.358089       82.018935
# 31    NM         35.700165       77.742152
# 32    NY         19.219967       78.701268
# 33    NC         35.435305       74.169609
# 34    ND         18.022838       82.236594
# 35    OH         30.456911       77.142255
# 36    OK         32.571073       80.961105
# 37    OR         29.343112       72.987560
# 38    PA         22.149142       82.845628
# 39    RI         23.299302       76.272162
# 40    SC         39.363444       71.157692
# 41    SD         15.999753       69.507344
# 42    TN         37.898152       79.161903
# 43    TX         36.468525       52.823141
# 44    UT         29.217730       78.624547
# 46    VA         22.029012       83.291245

# %%
import scipy.stats as st
# The next example will compute the Pearson correlation coefficient between "Income per Capita" and "Average Alcohol Consumed"
grad = merge_crime_Grad.iloc[:,2]
crime = merge_crime_Grad.iloc[:,1]
correlation = st.pearsonr(grad,crime)
image =  plt.scatter(grad,crime, )
image.set_facecolor("xkcd:black")
ax = plt.axes()
# Setting the background color
ax.set_facecolor("grey")

plt.xlabel('Graduation rate mean')
plt.ylabel('Crime Rate ')
print(f"The correlation between both factors is {round(correlation[0],2)}")
plt.show()
# Out:
# The correlation between both factors is -0.51
# /Users/klcurtiss/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
crime_rates_2007.head(2)
# Out:
#    year state_abbr  population  violent_crime  homicide  rape_legacy  robbery  \
# 0  2007         AL     4627851          20775       412         1548     7398
# 1  2007         AK      683478           4520        43          545      581
#
#    aggravated_assault  property_crime  burglary  larceny  motor_vehicle_theft  \
# 0               11417          184082     45379   124465                14238
# 1                3351           23096      3734    16929                 2433
#
#    total_crime  crime_rate
# 0       409714    8.853224
# 1        55232    8.081021

# %%
crime_rates_2008.head(2)
# Out:
#    year state_abbr  population  violent_crime  homicide  rape_legacy  robbery  \
# 0  2008         AL     4661900          21110       351         1618     7346
# 1  2008         AK      686293           4475        27          447      645
#
#    aggravated_assault  property_crime  burglary  larceny  motor_vehicle_theft  \
# 0               11795          190416     50411   126539                13466
# 1                3356           20090      3237    15225                 1628
#
#    total_crime  crime_rate
# 0       423052    9.074669
# 1        49130    7.158750

# %%
crime_rates_2009.head(2)
# Out:
#    year state_abbr  population  violent_crime  homicide  rape_legacy  robbery  \
# 0  2009         AL     4708708          21194       322         1504     6265
# 1  2009         AK      698473           4424        22          513      654
#
#    aggravated_assault  property_crime  burglary  larceny  motor_vehicle_theft  \
# 0               13103          178007     48844   118072                11091
# 1                3235           20538      3600    15251                 1687
#
#    total_crime  crime_rate
# 0       398402    8.460962
# 1        49924    7.147592

# %%
crime_rates_2006.head(2)
# Out:
#    year state_abbr  population  violent_crime  homicide  rape_legacy  robbery  \
# 0  2006         AL     4599030          19553       382         1646     7062
# 1  2006         AK      670053           4610        36          512      600
#
#    aggravated_assault  property_crime  burglary  larceny  motor_vehicle_theft  \
# 0               10463          181249     44780   121451                15018
# 1                3462           23975      4155    17284                 2536
#
#    total_crime  crime_rate
# 0       401604    8.732363
# 1        57170    8.532161

# %%
crimerate_summary_table = pd.DataFrame({
    "Motor_vehicle_theft_2006" : crime_rates_2006["motor_vehicle_theft"],
    "Motor_vehicle_theft_2007" : crime_rates_2007["motor_vehicle_theft"],
    "Motor_vehicle_theft_2008" : crime_rates_2008["motor_vehicle_theft"],
    "Motor_vehicle_theft_2009" : crime_rates_2009["motor_vehicle_theft"]
})
crimerate_summary_table
# Out:
#     Motor_vehicle_theft_2006  Motor_vehicle_theft_2007  \
# 0                      15018                     14238
# 1                       2536                      2433
# 2                      56650                     50244
# 3                       7515                      6999
# 4                     243655                    220134
# 5                      20656                     16656
# 6                      10290                      9951
# 7                       2884                      2342
# 8                       7321                      7606
# 9                      76454                     73630
# 10                     43127                     42518
# 11                      7739                      6283
# 12                      2436                      2266
# 13                     37641                     33887
# 14                     21590                     19403
# 15                      5044                      4939
# 16                      8724                      8600
# 17                      9364                      8678
# 18                     15667                     15293
# 19                      1347                      1276
# 20                     30523                     28393
# 21                     17975                     15051
# 22                     50098                     41988
# 23                     13277                     12648
# 24                      8330                      7191
# 25                     25399                     23897
# 26                      1947                      2046
# 27                      5166                      5246
# 28                     27007                     22363
# 29                      1486                      1411
# 30                     24749                     21959
# 31                      9230                      8903
# 32                     32133                     28029
# 33                     30102                     27952
# 34                      1086                       982
# 35                     37977                     33955
# 36                     13438                     13600
# 37                     14637                     14637
# 38                     29708                     26511
# 39                      3609                      3195
# 40                     16685                     17104
# 41                       834                       784
# 42                     22653                     21718
# 43                     95425                     94000
# 44                      8371                      8915
# 45                       620                       649
# 46                     14799                     14101
# 47                     46434                     38120
# 48                      4057                      3477
# 49                     14028                     13458
# 50                       804                       813
#
#     Motor_vehicle_theft_2008  Motor_vehicle_theft_2009
# 0                      13466                     11091
# 1                       1628                      1687
# 2                      38587                     26437
# 3                       6543                      6097
# 4                     192529                    163833
# 5                      13349                     12480
# 6                       8891                      7461
# 7                       2557                      1906
# 8                       6465                      5532
# 9                      63515                     50259
# 10                     39644                     33163
# 11                      5116                      4857
# 12                      1660                      1472
# 13                     32572                     26676
# 14                     17500                     13837
# 15                      4376                      3904
# 16                      7405                      5958
# 17                      7657                      6096
# 18                     13564                     11589
# 19                      1179                      1022
# 20                     25333                     19619
# 21                     12755                     11864
# 22                     35755                     29345
# 23                     10195                      8546
# 24                      6252                      5439
# 25                     20757                     17428
# 26                      1777                      1612
# 27                      4225                      3509
# 28                     15938                     12398
# 29                      1407                      1127
# 30                     20180                     15504
# 31                      8017                      6502
# 32                     25093                     21871
# 33                     26727                     19954
# 34                       911                       913
# 35                     28451                     22660
# 36                     11023                     10466
# 37                     11377                      9977
# 38                     22492                     17822
# 39                      3203                      2402
# 40                     17670                     13617
# 41                       918                       866
# 42                     19203                     15016
# 43                     85384                     76569
# 44                      7308                      6937
# 45                       586                       449
# 46                     13347                     11690
# 47                     29134                     23747
# 48                      3164                      2757
# 49                     11541                      8932
# 50                       733                       757
